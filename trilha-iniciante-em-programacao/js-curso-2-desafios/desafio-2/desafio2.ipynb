// %%
function boasVindas() {
 console.log("Boas vindas")
}

// %%
let nome = prompt("Digite seu nome")

function exibeNome(nome){
    console.log(`Olá ${nome}!`)
}

// %%
function exibirDobro(numero){
 dobro = numero*2
 console.log(`O dobro do numero é ${dobro}`)
}

exibirDobro(numero)

// %%
let listaDeNumeros = [];
for (let repetição = 0; repetição < 3; repetição++){
let numero = parseInt(prompt("Digite um numero"));
listaDeNumeros.push(numero)
}

function exibirMedia(listaDeNumeros){
    let media = (listaDeNumeros [0]+listaDeNumeros [1]+listaDeNumeros [2] /3);
    console.log(`A media final é ${media}`)

}

exibirMedia(listaDeNumeros)
// Out:
// A media final é 9.666666666666666
