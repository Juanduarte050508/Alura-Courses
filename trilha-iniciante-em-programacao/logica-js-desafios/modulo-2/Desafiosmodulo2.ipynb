// %%
//Desafio Boa semana

let dia = prompt ("Qual o dia da semana é hoje?")

let sab = ("sabado")
let dom = ("domingo")

if (dia == sab ) 
{alert("Bom fim de semana!")}

else if (dia == dom ){alert("Bom fim de semana!")}
else alert("Boa semana!")

// %%
//Desafio Sinal Numero 

let numero = prompt ("Digite um numero")
if (numero > 0) {alert("Você digitou um numero positivo")} 
else {alert("Você digitou um numero negativo")}

// %%
//Desafio Pontuação 

let pontuação = prompt ("Digite sua pontuação")
if (numero > 100) {alert("Parabéns, você venceu!")}
else {alert ("Tente novamente para ganhar.")}
// Out:
// Stack trace:
// ReferenceError: numero is not defined
//     at <anonymous>:3:1
